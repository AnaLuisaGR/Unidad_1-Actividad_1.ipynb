# %% [markdown]
# <a href="https://colab.research.google.com/github/AnaLuisaGR/Unidad_1-Actividad_1.ipynb/blob/main/Seleccion_de_aspirantes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Proyecto 3: Selección de aspirantes
# Alumna: Ana Luisa González Reyes

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Ruta al archivo en su Google Drive
ruta_archivo = '/content/drive/MyDrive/Colab data/applicant_list_7.txt'

# Nombres de las columnas
nombres_columnas = ['nombre', 'apellido', 'EPH', 'ECH', 'EMA', 'ECS', 'ESP', 'OP1', 'OP2', 'OP3']

# Leer un archivo con datos separados por espacio
df = pd.read_csv(ruta_archivo, sep=' ', names=nombres_columnas)

df
# Out:
#        nombre   apellido  EPH  ECH  EMA  ECS  ESP          OP1          OP2  \
# 0     Jermine    Brunton   84   81   73   92   48      Physics  Engineering
# 1       Justo     Mirfin   71   77   61   60   41  Engineering      Biotech
# 2        Uzma  Naysmythe   60   94   75   71   80    Chemistry  Engineering
# 3       Koury      Wingo   71   81   81   83   59  Engineering      Biotech
# 4    Kentrell  Hillhouse   40   69   42   58   20  Mathematics  Engineering
# ..        ...        ...  ...  ...  ...  ...  ...          ...          ...
# 93     Tamkia       Fish   81   71   73   86   78      Physics  Engineering
# 94      Deniz  Blanchard   71   77   61   60   61  Engineering      Biotech
# 95       Mira      Riley   60   94   75   71   80  Engineering      Biotech
# 96      Loura    Macansh   71   81   81   93   79  Engineering      Physics
# 97  Nastassja   Trustram   60   49   82   68   70  Mathematics  Engineering
#
#             OP3
# 0   Mathematics
# 1     Chemistry
# 2   Mathematics
# 3   Mathematics
# 4       Biotech
# ..          ...
# 93  Mathematics
# 94    Chemistry
# 95  Mathematics
# 96  Mathematics
# 97      Physics
#
# [98 rows x 10 columns]

# %%
print(df.shape)
print(f"Número de filas: {df.shape[0]}")
print(f"Número de columnas: {df.shape[1]}")
# Out:
# (98, 10)
# Número de filas: 98
# Número de columnas: 10

# %%
display(df[['OP1','nombre']])
# Out:
#             OP1     nombre
# 0       Physics    Jermine
# 1   Engineering      Justo
# 2     Chemistry       Uzma
# 3   Engineering      Koury
# 4   Mathematics   Kentrell
# ..          ...        ...
# 93      Physics     Tamkia
# 94  Engineering      Deniz
# 95  Engineering       Mira
# 96  Engineering      Loura
# 97  Mathematics  Nastassja
#
# [98 rows x 2 columns]

# %%
df['nombre_completo'] = df['nombre']+' '+ df['apellido']
df
# Out:
#        nombre   apellido  EPH  ECH  EMA  ECS  ESP          OP1          OP2  \
# 0     Jermine    Brunton   84   81   73   92   48      Physics  Engineering
# 1       Justo     Mirfin   71   77   61   60   41  Engineering      Biotech
# 2        Uzma  Naysmythe   60   94   75   71   80    Chemistry  Engineering
# 3       Koury      Wingo   71   81   81   83   59  Engineering      Biotech
# 4    Kentrell  Hillhouse   40   69   42   58   20  Mathematics  Engineering
# ..        ...        ...  ...  ...  ...  ...  ...          ...          ...
# 93     Tamkia       Fish   81   71   73   86   78      Physics  Engineering
# 94      Deniz  Blanchard   71   77   61   60   61  Engineering      Biotech
# 95       Mira      Riley   60   94   75   71   80  Engineering      Biotech
# 96      Loura    Macansh   71   81   81   93   79  Engineering      Physics
# 97  Nastassja   Trustram   60   49   82   68   70  Mathematics  Engineering
#
#             OP3     nombre_completo  PROMEDIO  OP2_score  OP3_score
# 0   Mathematics     Jermine Brunton      75.6      74.25      73.67
# 1     Chemistry        Justo Mirfin      62.0      59.75      63.00
# 2   Mathematics      Uzma Naysmythe      76.0      71.50      81.67
# 3   Mathematics         Koury Wingo      75.0      76.00      74.33
# 4       Biotech  Kentrell Hillhouse      45.8      40.00      47.25
# ..          ...                 ...       ...        ...        ...
# 93  Mathematics         Tamkia Fish      77.8      79.50      78.33
# 94    Chemistry     Deniz Blanchard      66.0      64.75      69.67
# 95  Mathematics          Mira Riley      76.0      80.00      81.67
# 96  Mathematics       Loura Macansh      81.0      77.00      84.33
# 97      Physics  Nastassja Trustram      65.8      70.00      70.67
#
# [98 rows x 14 columns]

# %%
# definición de una función para calcular el puntaje de admisión
def calcular_puntaje_admision(linea, opcion):
  departamento = linea[opcion]
  if departamento == 'Physics':
    puntaje = (linea['EPH'] + linea['EMA'] + linea['ESP']) / 3
  elif departamento == 'Mathematics':
      puntaje = (linea['ECH'] + linea['ECS'] + linea['ESP']) / 3
  elif departamento == 'Engineering':
      puntaje = (linea['EMA'] + linea['ECS'] + linea['EPH'] + linea['ESP']) / 4
  elif departamento == 'Chemistry':
      puntaje = (linea['ECH'] + linea['EPH'] + linea['ESP']) / 3
  elif departamento == 'Biotech':
      puntaje = (linea['EMA'] + linea['ECS'] + linea['ECH'] + linea['ESP']) / 4
  else:
      return None
  return round(puntaje, 2)

  df['OP1score'] = df.apply(lambda x: calcular_puntaje_admision(x, 'OP1'), axis=1)
  df

df['OP1_score'] = df.apply(lambda r: calcular_puntaje_admision(r, 'OP1'), axis=1)
df['OP2_score'] = df.apply(lambda r: calcular_puntaje_admision(r, 'OP2'), axis=1)
df['OP3_score'] = df.apply(lambda r: calcular_puntaje_admision(r, 'OP3'), axis=1)

df
# Out:
#        nombre   apellido  EPH  ECH  EMA  ECS  ESP          OP1          OP2  \
# 0     Jermine    Brunton   84   81   73   92   48      Physics  Engineering
# 1       Justo     Mirfin   71   77   61   60   41  Engineering      Biotech
# 2        Uzma  Naysmythe   60   94   75   71   80    Chemistry  Engineering
# 3       Koury      Wingo   71   81   81   83   59  Engineering      Biotech
# 4    Kentrell  Hillhouse   40   69   42   58   20  Mathematics  Engineering
# ..        ...        ...  ...  ...  ...  ...  ...          ...          ...
# 93     Tamkia       Fish   81   71   73   86   78      Physics  Engineering
# 94      Deniz  Blanchard   71   77   61   60   61  Engineering      Biotech
# 95       Mira      Riley   60   94   75   71   80  Engineering      Biotech
# 96      Loura    Macansh   71   81   81   93   79  Engineering      Physics
# 97  Nastassja   Trustram   60   49   82   68   70  Mathematics  Engineering
#
#             OP3     nombre_completo  PROMEDIO  OP2_score  OP3_score  OP1_score
# 0   Mathematics     Jermine Brunton      75.6      74.25      73.67      68.33
# 1     Chemistry        Justo Mirfin      62.0      59.75      63.00      58.25
# 2   Mathematics      Uzma Naysmythe      76.0      71.50      81.67      78.00
# 3   Mathematics         Koury Wingo      75.0      76.00      74.33      73.50
# 4       Biotech  Kentrell Hillhouse      45.8      40.00      47.25      49.00
# ..          ...                 ...       ...        ...        ...        ...
# 93  Mathematics         Tamkia Fish      77.8      79.50      78.33      77.33
# 94    Chemistry     Deniz Blanchard      66.0      64.75      69.67      63.25
# 95  Mathematics          Mira Riley      76.0      80.00      81.67      71.50
# 96  Mathematics       Loura Macansh      81.0      77.00      84.33      81.00
# 97      Physics  Nastassja Trustram      65.8      70.00      70.67      62.33
#
# [98 rows x 15 columns]

# %%
departmentos = ["Biotech", "Chemistry", "Engineering", "Mathematics", "Physics"]

while True:
  departamento_seleccionado = input("Introduce el departamento para la selección (Biotech, Chemistry, Engineering, Mathematics, Physics): ")
  if departamento_seleccionado in departmentos:
    break
  else:
    print("Departamento inválido. Por favor, elige uno de la lista.")

print(f"Departamento seleccionado: {departamento_seleccionado}")
# Out:
# Introduce el departamento para la selección (Biotech, Chemistry, Engineering, Mathematics, Physics): Engineering
# Departamento seleccionado: Engineering

# %%
aspirantes_departamento = df[(df['OP1'] == departamento_seleccionado)]

aspirantes_ordenados = aspirantes_departamento.sort_values(by=['OP1_score'], ascending=[False])
aspirantes_ordenados
df
# Out:
#        nombre   apellido  EPH  ECH  EMA  ECS  ESP          OP1          OP2  \
# 0     Jermine    Brunton   84   81   73   92   48      Physics  Engineering
# 1       Justo     Mirfin   71   77   61   60   41  Engineering      Biotech
# 2        Uzma  Naysmythe   60   94   75   71   80    Chemistry  Engineering
# 3       Koury      Wingo   71   81   81   83   59  Engineering      Biotech
# 4    Kentrell  Hillhouse   40   69   42   58   20  Mathematics  Engineering
# ..        ...        ...  ...  ...  ...  ...  ...          ...          ...
# 93     Tamkia       Fish   81   71   73   86   78      Physics  Engineering
# 94      Deniz  Blanchard   71   77   61   60   61  Engineering      Biotech
# 95       Mira      Riley   60   94   75   71   80  Engineering      Biotech
# 96      Loura    Macansh   71   81   81   93   79  Engineering      Physics
# 97  Nastassja   Trustram   60   49   82   68   70  Mathematics  Engineering
#
#             OP3     nombre_completo  PROMEDIO  OP2_score  OP3_score  OP1_score
# 0   Mathematics     Jermine Brunton      75.6      74.25      73.67      68.33
# 1     Chemistry        Justo Mirfin      62.0      59.75      63.00      58.25
# 2   Mathematics      Uzma Naysmythe      76.0      71.50      81.67      78.00
# 3   Mathematics         Koury Wingo      75.0      76.00      74.33      73.50
# 4       Biotech  Kentrell Hillhouse      45.8      40.00      47.25      49.00
# ..          ...                 ...       ...        ...        ...        ...
# 93  Mathematics         Tamkia Fish      77.8      79.50      78.33      77.33
# 94    Chemistry     Deniz Blanchard      66.0      64.75      69.67      63.25
# 95  Mathematics          Mira Riley      76.0      80.00      81.67      71.50
# 96  Mathematics       Loura Macansh      81.0      77.00      84.33      81.00
# 97      Physics  Nastassja Trustram      65.8      70.00      70.67      62.33
#
# [98 rows x 15 columns]

# %%
# Filtrar el DataFrame para el departamento seleccionado y la opción OP1
aspirantes_departamento = df[(df['OP1'] == departamento_seleccionado)]

# Ordenar por OP1_score en orden descendente
aspirantes_ordenados = aspirantes_departamento.sort_values(by=['OP1_score'], ascending=[False])

# Seleccionar los N aspirantes con los puntajes más altos
aspirantes_elegidos = aspirantes_ordenados.head(N)

# Crear la tabla con las columnas especificadas
tabla_aspirantes_elegidos = pd.DataFrame({
    'nombre_completo': aspirantes_elegidos['nombre_completo'],
    'departmento': aspirantes_elegidos['OP1'],
    'puntaje': aspirantes_elegidos['OP1_score'],
    'opcion': 'OP1'
})

# Presentar el contenido de la tabla
display(tabla_aspirantes_elegidos)

# Imprimir el número de aspirantes elegidos
print(f"\nNúmero de aspirantes elegidos para {departamento_seleccionado} (OP1): {len(tabla_aspirantes_elegidos)}")
# Out:
#           nombre_completo  departmento  puntaje opcion
# 23  Meshell Otway-Ruthven  Engineering    87.50    OP1
# 39           Jamarl Delap  Engineering    87.25    OP1
# 87           Melena Hearn  Engineering    87.25    OP1
# 35         Tawsha Rodgers  Engineering    85.25    OP1
# 11        Ruthanne Scaife  Engineering    84.50    OP1
# Número de aspirantes elegidos para Engineering (OP1): 5
